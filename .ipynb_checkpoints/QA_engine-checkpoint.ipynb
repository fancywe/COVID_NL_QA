# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import random
import warnings
import numpy as np

warnings.simplefilter("ignore")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, confusion_matrix, plot_confusion_matrix, plot_precision_recall_curve

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.3-py3-none-win_amd64.whl (89.1 MB)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (from xgboost) (1.21.1)
# Requirement already satisfied: scipy in e:\anaconda\lib\site-packages (from xgboost) (1.7.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv('Training set.csv')

# %%
data
# Out:
#                                              Question  Type
# 0               What's the overall COVID status in US     1
# 1         How's the Covid going in American this week     1
# 2            How many new case in United States today     1
# 3        How's everything goes in Wisconsin this week     2
# 4                                           Wisconsin     2
# 5                        The overall data of Illinois     2
# 6        what's the Covid data overview in California     2
# 7                 How many new case in Ohio this week     3
# 8   Show me the case trend in New York state this ...     3
# 9           The case graph in South Dekota these days     3
# 10                Show me the COVID trend in American     1
# 11                        The case trend in Minnesota     3
# 12                          The Covid status in Miami     2
# 13                 How many death in Alaska this week     4
# 14              How many people died in LA these days     4
# 15               what's the postive rate in  Missouri     5
# 16     What's the test situation in Florida this week     5
# 17        COVID Inpatient Beds Used in South Carolina     6
# 18              What's the hospital usage in NJ state     6
# 19        How's the Vaccine situation in NY state now     7
# 20         Show me the vaccination in US Pennsylvania     7
# 21                                       La Crosse WI    10
# 22                       Covid Level in Union of Iowa    10
# 23  Tell me something about the Covid in Madison W...    10
# 24               The overall data of Chicago Illinois    10
# 25                        Covid going in La Crosse WI    10
# 26      How many new case in Adams county of Colorado    11
# 27     How many new cases in Irion of Texas this week    11
# 28      Show me the case trend in AL Bethel this week    11
# 29                 Death status in Washington Vermont    12
# 30   how many death cause of Coivd in WI Clark county    12
# 31       I want to know the Test info of Valley Idaho    13
# 32  How many postive we have in St. Charles Louisiana    13
# 33                      Postive rate in Clay Arkansas    13
# 34          Hospitality in Clay county North Carolina    14
# 35              Hospital usage in La Crosse Wisconsin    14
# 36                       ICU occupation in Davis Utah    14
# 37                        vaccination in La Crosse WI    15
# 38  How many people recived boost dose in Lee Kent...    15
# 39   what's the vaccination rate in Lincoln Louisiana    15
# 40                        New deaths in New Hampshire     4
# 41  The number of new accidental deaths in the Dak...     4
# 42  Carolina NC,how many people went to see God th...     4
# 43                     Nucleic acid detection of Iowa     5
# 44  How many people are negative in the nucleic ac...     5
# 45  The proportion of children participating in nu...     5
# 46  Are there many people in hospitals in Kansas a...     6
# 47  Are all the severe cases in COVID-19 in  New H...     6
# 48   How many doctors are there in Colorado Hospital?     6
# 49  Do we need to count the vaccination situation ...     7
# 50  How does the vaccination rate inLouisiana comp...     7
# 51          What is the vaccination rate in Maryland?     7
# 52  The number of COVID-19 patients in County Nowa...    14
# 53  The number of COVID-19 patients in Bolivar cou...    14
# 54                       hey,what's the weather today    20
# 55                         do we have taco for lunch?    20
# 56                                hey you little shit    20
# 57                      What's new case in St.Paul MN    11
# 58                 How many new death in MN this week     4
# 59                                                 MN     2

# %%
train =data[:56]
trainX = data['Question']
trainY = data['Type'].values
train
# Out:
#                                              Question  Type
# 0               What's the overall COVID status in US     1
# 1         How's the Covid going in American this week     1
# 2            How many new case in United States today     1
# 3        How's everything goes in Wisconsin this week     2
# 4                                           Wisconsin     2
# 5                        The overall data of Illinois     2
# 6        what's the Covid data overview in California     2
# 7                 How many new case in Ohio this week     3
# 8   Show me the case trend in New York state this ...     3
# 9           The case graph in South Dekota these days     3
# 10                Show me the COVID trend in American     1
# 11                        The case trend in Minnesota     3
# 12                          The Covid status in Miami     2
# 13                 How many death in Alaska this week     4
# 14              How many people died in LA these days     4
# 15               what's the postive rate in  Missouri     5
# 16     What's the test situation in Florida this week     5
# 17        COVID Inpatient Beds Used in South Carolina     6
# 18              What's the hospital usage in NJ state     6
# 19        How's the Vaccine situation in NY state now     7
# 20         Show me the vaccination in US Pennsylvania     7
# 21                                       La Crosse WI    10
# 22                       Covid Level in Union of Iowa    10
# 23  Tell me something about the Covid in Madison W...    10
# 24               The overall data of Chicago Illinois    10
# 25                        Covid going in La Crosse WI    10
# 26      How many new case in Adams county of Colorado    11
# 27     How many new cases in Irion of Texas this week    11
# 28      Show me the case trend in AL Bethel this week    11
# 29                 Death status in Washington Vermont    12
# 30   how many death cause of Coivd in WI Clark county    12
# 31       I want to know the Test info of Valley Idaho    13
# 32  How many postive we have in St. Charles Louisiana    13
# 33                      Postive rate in Clay Arkansas    13
# 34          Hospitality in Clay county North Carolina    14
# 35              Hospital usage in La Crosse Wisconsin    14
# 36                       ICU occupation in Davis Utah    14
# 37                        vaccination in La Crosse WI    15
# 38  How many people recived boost dose in Lee Kent...    15
# 39   what's the vaccination rate in Lincoln Louisiana    15
# 40                        New deaths in New Hampshire     4
# 41  The number of new accidental deaths in the Dak...     4
# 42  Carolina NC,how many people went to see God th...     4
# 43                     Nucleic acid detection of Iowa     5
# 44  How many people are negative in the nucleic ac...     5
# 45  The proportion of children participating in nu...     5
# 46  Are there many people in hospitals in Kansas a...     6
# 47  Are all the severe cases in COVID-19 in  New H...     6
# 48   How many doctors are there in Colorado Hospital?     6
# 49  Do we need to count the vaccination situation ...     7
# 50  How does the vaccination rate inLouisiana comp...     7
# 51          What is the vaccination rate in Maryland?     7
# 52  The number of COVID-19 patients in County Nowa...    14
# 53  The number of COVID-19 patients in Bolivar cou...    14
# 54                       hey,what's the weather today    20
# 55                         do we have taco for lunch?    20

# %%
valid = data[56:59]
validX = valid['Question']
validY = valid['Type'].values
valid
# Out:
#                               Question  Type
# 56                 hey you little shit    20
# 57       What's new case in St.Paul MN    11
# 58  How many new death in MN this week     4

# %%
vectorizer = TfidfVectorizer()

trainX = vectorizer.fit_transform(trainX)
validX = vectorizer.transform(validX)

# %%
lr_classifier = LogisticRegression(C=1.)
lr_classifier.fit(trainX, trainY)
# Out:
# LogisticRegression()

# %%
print(f"Validation Accuracy of Logsitic Regression Classifier is: {(lr_classifier.score(validX, validY))*100:.2f}%")
# Out:
# Validation Accuracy of Logsitic Regression Classifier is: 100.00%

# %%
def plot_metric(clf, testX, testY, name):
    """
    Small function to plot ROC-AUC values and confusion matrix
    """
    styles = ['bmh', 'classic', 'fivethirtyeight', 'ggplot']

    plt.style.use(random.choice(styles))
    plot_confusion_matrix(clf, testX, testY)
    plt.title(f"Confusion Matrix [{name}]")

# %%
plot_metric(lr_classifier, validX, validY, "Logistic Regression")

# %%
TestX = vectorizer.transform(['IL'])

print(lr_classifier.predict(TestX))
# Out:
# [2]
